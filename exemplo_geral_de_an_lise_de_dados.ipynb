# %% [markdown]
# <a href="https://colab.research.google.com/github/GuilhermeFer29/Analise_de_dados_IFPR/blob/main/exemplo_geral_de_an_lise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de Dados de vendas de uma empresa fictícia nos Estados Unidos
#
#
# *   Responda às questões de negócio.
# *   Utilize os conhecimentos adquiridos ao longo do curso e também as bibliotecas: numpy, pandas, matplotlib e seaborn.

# %% [markdown]
# ## Pergundas de negócio
#
#
# 1. Análise exploratória (medidas estatísticas)
# 2. Qual cidade com maior valor de venda de produtos na Categoria "Suprimentos de Escritório"?
# 3. Qual o total de vendas por data do pedido? Demonstre o resultado por meio de um gráfico de linhas.
# 4. Qual o valor total de vendas por estado? Utilize um gráfico de barras.
# 5. Quais são as 10 cidades com maior total de vendas? Utilize um gráfico de barras.
# 6. Quais as 20 cidades com menor total de vendas? Utilzie um gráfico de barras.
# 7. Qual o segmento teve o maior total de vendas? Utilize um gráfico de pizza.
# 8. Qual o total de vendas por segmento e por ano?

# %% [markdown]
# ##Preparação das bibliotecas e carregamento dos dados

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_excel('dataset.xlsx')

# %% [markdown]
# ###1. Análise exploratória (medidas estatísticas)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9700 entries, 0 to 9699
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID_Pedido     9700 non-null   object
#  1   Data_Pedido   9700 non-null   object
#  2   ID_Cliente    9700 non-null   object
#  3   Segmento      9700 non-null   object
#  4   Pais          9700 non-null   object
#  5   Cidade        9700 non-null   object
#  6   Estado        9700 non-null   object
#  7   ID_Produto    9700 non-null   object
#  8   Categoria     9700 non-null   object
#  9   SubCategoria  9700 non-null   object
#  10  Valor_Venda   9700 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 833.7+ KB

# %%
dados.describe()
# Out:
#         Valor_Venda
# count  9.700000e+03
# mean   8.352892e+04
# std    3.327765e+05
# min    9.900000e-01
# 25%    3.990000e+01
# 50%    3.516800e+02
# 75%    2.403600e+04
# max    1.119997e+07

# %%
dados.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumidor  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumidor  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporativo  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumidor  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumidor  United States
#
#             Cidade      Estado       ID_Produto               Categoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798                 Mobília
# 1        Henderson    Kentucky  FUR-CH-10000454                 Mobília
# 2      Los Angeles  California  OFF-LA-10000240  Material de Escritório
# 3  Fort Lauderdale     Florida  FUR-TA-10000577                 Mobília
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Material de Escritório
#
#             SubCategoria  Valor_Venda
# 0           Prateleiras      261.9600
# 1               Cadeiras     731.9400
# 2              Etiquetas      14.6200
# 3                  Mesas     957.5775
# 4  Pasta para documentos   22368.0000

# %% [markdown]
# ###2. Qual cidade com maior valor de venda de produtos na Categoria "Material  de Escritório"?

# %%
dados2 = dados[dados['Categoria'] == 'Material de Escritório']
dados2 = dados2.groupby('Cidade').sum()
dados2  = dados2.sort_values('Valor_Venda', ascending=False)
dados2.head()
# Out:
#                                                        ID_Pedido  \
# Cidade
# Philadelphia   US-2016-150630US-2016-150630US-2016-150630US-2...
# New York City  CA-2017-105816CA-2017-106075CA-2016-137225CA-2...
# Seattle        CA-2017-161389CA-2016-118948CA-2017-113817CA-2...
# Houston        CA-2018-107727CA-2016-117415US-2018-118038US-2...
# Chicago        US-2018-119662CA-2017-158568CA-2017-158568US-2...
#
#                                                      Data_Pedido  \
# Cidade
# Philadelphia   17/09/201617/09/201617/09/201617/09/201617/09/...
# New York City  11/12/201718/09/201715/12/201612/10/201612/10/...
# Seattle        05/12/201728/05/201607/11/201703/11/201815/12/...
# Houston        19/10/201827/12/201609/12/201809/12/201805/04/...
# Chicago        13/11/201829/08/201729/08/201714/09/201514/09/...
#
#                                                       ID_Cliente  \
# Cidade
# Philadelphia   TB-21520TB-21520TB-21520TB-21520TB-21520FH-143...
# New York City  JM-15265HM-14980JK-15640MP-17470MP-17470DL-133...
# Seattle        IM-15070NK-18490MJ-17740KC-16675JH-15985JH-159...
# Houston        MA-17560SN-20710KB-16600KB-16600GM-14455SJ-205...
# Chicago        CS-12400RB-19465RB-19465JB-15400JB-15400KL-166...
#
#                                                         Segmento  \
# Cidade
# Philadelphia   ConsumidorConsumidorConsumidorConsumidorConsum...
# New York City  CorporativoConsumidorDomésticoDomésticoDomésti...
# Seattle        ConsumidorDomésticoConsumidorCorporativoConsum...
# Houston        DomésticoDomésticoCorporativoCorporativoDomést...
# Chicago        DomésticoDomésticoDomésticoCorporativoCorporat...
#
#                                                             Pais  \
# Cidade
# Philadelphia   United StatesUnited StatesUnited StatesUnited ...
# New York City  United StatesUnited StatesUnited StatesUnited ...
# Seattle        United StatesUnited StatesUnited StatesUnited ...
# Houston        United StatesUnited StatesUnited StatesUnited ...
# Chicago        United StatesUnited StatesUnited StatesUnited ...
#
#                                                           Estado  \
# Cidade
# Philadelphia   PennsylvaniaPennsylvaniaPennsylvaniaPennsylvan...
# New York City  New YorkNew YorkNew YorkNew YorkNew YorkNew Yo...
# Seattle        WashingtonWashingtonWashingtonWashingtonWashin...
# Houston        TexasTexasTexasTexasTexasTexasTexasTexasTexasT...
# Chicago        IllinoisIllinoisIllinoisIllinoisIllinoisIllino...
#
#                                                       ID_Produto  \
# Cidade
# Philadelphia   OFF-BI-10000474OFF-EN-10001509OFF-AR-10004042O...
# New York City  OFF-FA-10000304OFF-BI-10004654OFF-AR-10001940O...
# Seattle        OFF-BI-10003656OFF-AR-10001547OFF-BI-10004002O...
# Houston        OFF-PA-10000249OFF-EN-10002986OFF-BI-10004182O...
# Chicago        OFF-ST-10003656OFF-PA-10003256OFF-BI-10002609O...
#
#                                                        Categoria  \
# Cidade
# Philadelphia   Material de EscritórioMaterial de EscritórioMa...
# New York City  Material de EscritórioMaterial de EscritórioMa...
# Seattle        Material de EscritórioMaterial de EscritórioMa...
# Houston        Material de EscritórioMaterial de EscritórioMa...
# Chicago        Material de EscritórioMaterial de EscritórioMa...
#
#                                                     SubCategoria  Valor_Venda
# Cidade
# Philadelphia   FicháriosEnvelopesDecoraçãoFicháriosDecoraçãoF...  22128529.35
# New York City  Grampos com trilhoFicháriosDecoraçãoPapelDecor...  20953440.83
# Seattle        FicháriosDecoraçãoFicháriosPapelFragmentadoraF...  13002284.47
# Houston        PapelEnvelopesFicháriosPasta para documentosPa...  12857337.21
# Chicago        Pasta para documentosPapelFicháriosFragmentado...   8504885.81

# %% [markdown]
# ###3. Qual o total de vendas por data do pedido? Demonstre o resultado por meio de um gráfico de linhas.

# %%
dados3 = dados.groupby('Data_Pedido').sum().reset_index()
dados3.plot(x='Data_Pedido', y='Valor_Venda', kind='line' , figsize=(10,5))
plt.title('Total de vendas por data do pedido')
plt.xlabel('Data')
# Out:
# <Axes: xlabel='Data_Pedido'>

# %% [markdown]
# ###4. Qual o valor total de vendas por estado? Utilize um gráfico de barras.

# %% [markdown]
# ###5. Quais são as 10 cidades com maior total de vendas? Utilize um gráfico de barras.

# %% [markdown]
# ###6. Quais as 20 cidades com menor total de vendas? Utilzie um gráfico de barras.

# %% [markdown]
# ###7. Qual o segmento teve o maior total de vendas? Utilize um gráfico de pizza.

# %% [markdown]
# ###8. Qual o total de vendas por segmento e por ano?
